# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
import os  
import os.path
from xml.etree.ElementTree import parse, Element

def test():
    path="E:/Users/workspace/pythonProject/pythonProject/pythonProject/pythonProject/SSD/VOCdevkit/VOC2007/Annotations"                
    files=os.listdir(path)  #得到文件夹下所有文件名称  
    s=[]  
    for xmlFile in files: #遍历文件夹  
        if not os.path.isdir(xmlFile): #判断是否是文件夹,不是文件夹才打开  
            print(xmlFile)
            pass
        path="E:/Users/workspace/pythonProject/pythonProject/pythonProject/pythonProject/SSD/VOCdevkit/VOC2007/Annotations"
        newStr=os.path.join(path,xmlFile)  
        dom=parse(newStr)  ###最核心的部分,路径拼接,输入的是具体路径  
        root=dom.getroot()
        #print root
        part=xmlFile[0:7]
        part1=part+'jpg'
#         newStr1='E:/Users/workspace/pythonProject/pythonProject/pythonProject/pythonProject/SSD/VOCdevkit/VOC2007/'+part1           

#         root.find('path').text=newStr1
        newStr1='VOC2007'
        root.find('folder').text=newStr1
    
        # #打印输出  
        print('path after change')  
      
        dom.write(newStr, xml_declaration=True)
        pass


if __name__=='__main__':
    test()
# Out:
# 000-0.xml
# path after change
# 000002.xml
# path after change
# 000003.xml
# path after change
# 000004.xml
# path after change
# 000005.xml
# path after change
# 000007.xml
# path after change
# 000010.xml
# path after change
# 000011.xml
# path after change
# 000012.xml
# path after change
# 000013.xml
# path after change
# 000015.xml
# path after change
# 000016.xml
# path after change
# 000018.xml
# path after change
# 000019.xml
# path after change
# 000020.xml
# path after change
# 000021.xml
# path after change
# 000022.xml
# path after change
# 000023.xml
# path after change
# 000024.xml
# path after change
# 000025.xml
# path after change
# 000026.xml
# path after change
# 000027.xml
# path after change
# 000028.xml
# path after change
# 000030.xml
# path after change
# 000031.xml
# path after change
# 000032.xml
# path after change
# 000033.xml
# path after change
# 000034.xml
# path after change
# 000035.xml
# path after change
# 000036.xml
# path after change
# ...
